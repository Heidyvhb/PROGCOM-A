# %% [markdown]
# ![Captura de pantalla 2025-03-20 222619.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-03-20 222656.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-03-20 222712.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-03-20 222733.png](data:image/png;base64,...)
